# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pickle


g = 1e-3 # grams to kg
mol = 6.023e23 # Avogadros Number

mass_PP = 42 *g/mol # Mass of PP Monomer in kg
mass_PS = 104 * g/mol # Mass of PS Monomer in kg

font = {'family' : 'Times New Roman',
        'size'   : 10}

mpl.rc('font', **font)
mpl.rc('lines', linewidth=1)

# %%
with open(f'PS_tacticityspread_40_monomers.pickle', 'rb') as f:
    all_master = pickle.load(f)

all_40M_0 = all_master['0']
all_40M_10 = all_master['10']
all_40M_20 = all_master['20']
all_40M_30 = all_master['30']
all_40M_40 = all_master['40']
all_40M_50 = all_master['50']
all_40M_60 = all_master['60']
all_40M_70 = all_master['70']
all_40M_80 = all_master['80']
all_40M_90 = all_master['90']
all_40M_100 = all_master['100']

all_k_0_40M, all_dk_0_40M = [], []
all_tacticity_0_40M, all_T_0_40M, all_dT_0_40M, all_L_0_40M, all_Cv_0_40M = [], [], [], [], []
all_orientations_0_40M = []
for key in all_40M_0.keys():
    all_tacticity_0_40M.extend(all_40M_0[key]['Tacticity'])
    all_k_0_40M.extend(all_40M_0[key]['k'])
    all_dk_0_40M.extend(all_40M_0[key]['dk'])
    all_T_0_40M.extend(all_40M_0[key]['Tension'])
    all_dT_0_40M.extend(all_40M_0[key]['dTension'])
    all_L_0_40M.extend(all_40M_0[key]['L'])
    all_Cv_0_40M.extend(all_40M_0[key]['Cv'])
    all_orientations_0_40M.extend(all_40M_0[key]['Orientation'])

all_k_10_40M, all_dk_10_40M = [], []
all_tacticity_10_40M, all_T_10_40M, all_dT_10_40M, all_L_10_40M, all_Cv_10_40M = [], [], [], [], []
all_orientations_10_40M = []
for key in all_40M_10.keys():
    all_tacticity_10_40M.extend(all_40M_10[key]['Tacticity'])
    all_k_10_40M.extend(all_40M_10[key]['k'])
    all_dk_10_40M.extend(all_40M_10[key]['dk'])
    all_T_10_40M.extend(all_40M_10[key]['Tension'])
    all_dT_10_40M.extend(all_40M_10[key]['dTension'])
    all_L_10_40M.extend(all_40M_10[key]['L'])
    all_Cv_10_40M.extend(all_40M_10[key]['Cv'])
    all_orientations_10_40M.extend(all_40M_10[key]['Orientation'])

all_k_20_40M, all_dk_20_40M = [], []
all_tacticity_20_40M, all_T_20_40M, all_dT_20_40M, all_L_20_40M, all_Cv_20_40M = [], [], [], [], []
all_orientations_20_40M = []
for key in all_40M_20.keys():
    all_tacticity_20_40M.extend(all_40M_20[key]['Tacticity'])
    all_k_20_40M.extend(all_40M_20[key]['k'])
    all_dk_20_40M.extend(all_40M_20[key]['dk'])
    all_T_20_40M.extend(all_40M_20[key]['Tension'])
    all_dT_20_40M.extend(all_40M_20[key]['dTension'])
    all_L_20_40M.extend(all_40M_20[key]['L'])
    all_Cv_20_40M.extend(all_40M_20[key]['Cv'])
    all_orientations_20_40M.extend(all_40M_20[key]['Orientation'])

all_k_30_40M, all_dk_30_40M = [], []
all_tacticity_30_40M, all_T_30_40M, all_dT_30_40M, all_L_30_40M, all_Cv_30_40M = [], [], [], [], []
all_orientations_30_40M = []
for key in all_40M_30.keys():
    all_tacticity_30_40M.extend(all_40M_30[key]['Tacticity'])
    all_k_30_40M.extend(all_40M_30[key]['k'])
    all_dk_30_40M.extend(all_40M_30[key]['dk'])
    all_T_30_40M.extend(all_40M_30[key]['Tension'])
    all_dT_30_40M.extend(all_40M_30[key]['dTension'])
    all_L_30_40M.extend(all_40M_30[key]['L'])
    all_Cv_30_40M.extend(all_40M_30[key]['Cv'])
    all_orientations_30_40M.extend(all_40M_30[key]['Orientation'])

all_k_40_40M, all_dk_40_40M = [], []
all_tacticity_40_40M, all_T_40_40M, all_dT_40_40M, all_L_40_40M, all_Cv_40_40M = [], [], [], [], []
all_orientations_40_40M = []
for key in all_40M_40.keys():
    all_tacticity_40_40M.extend(all_40M_40[key]['Tacticity'])
    all_k_40_40M.extend(all_40M_40[key]['k'])
    all_dk_40_40M.extend(all_40M_40[key]['dk'])
    all_T_40_40M.extend(all_40M_40[key]['Tension'])
    all_dT_40_40M.extend(all_40M_40[key]['dTension'])
    all_L_40_40M.extend(all_40M_40[key]['L'])
    all_Cv_40_40M.extend(all_40M_40[key]['Cv'])
    all_orientations_40_40M.extend(all_40M_40[key]['Orientation'])

all_k_50_40M, all_dk_50_40M = [], []
all_tacticity_50_40M, all_T_50_40M, all_dT_50_40M, all_L_50_40M, all_Cv_50_40M = [], [], [], [], []
all_orientations_50_40M = []
for key in all_40M_50.keys():
    all_tacticity_50_40M.extend(all_40M_50[key]['Tacticity'])
    all_k_50_40M.extend(all_40M_50[key]['k'])
    all_dk_50_40M.extend(all_40M_50[key]['dk'])
    all_T_50_40M.extend(all_40M_50[key]['Tension'])
    all_dT_50_40M.extend(all_40M_50[key]['dTension'])
    all_L_50_40M.extend(all_40M_50[key]['L'])
    all_Cv_50_40M.extend(all_40M_50[key]['Cv'])
    all_orientations_50_40M.extend(all_40M_50[key]['Orientation'])

all_k_60_40M, all_dk_60_40M = [], []
all_tacticity_60_40M, all_T_60_40M, all_dT_60_40M, all_L_60_40M, all_Cv_60_40M = [], [], [], [], []
all_orientations_60_40M = []
for key in all_40M_60.keys():
    all_tacticity_60_40M.extend(all_40M_60[key]['Tacticity'])
    all_k_60_40M.extend(all_40M_60[key]['k'])
    all_dk_60_40M.extend(all_40M_60[key]['dk'])
    all_T_60_40M.extend(all_40M_60[key]['Tension'])
    all_dT_60_40M.extend(all_40M_60[key]['dTension'])
    all_L_60_40M.extend(all_40M_60[key]['L'])
    all_Cv_60_40M.extend(all_40M_60[key]['Cv'])
    all_orientations_60_40M.extend(all_40M_60[key]['Orientation'])


all_k_70_40M, all_dk_70_40M = [], []
all_tacticity_70_40M, all_T_70_40M, all_dT_70_40M, all_L_70_40M, all_Cv_70_40M = [], [], [], [], []
all_orientations_70_40M = []
for key in all_40M_70.keys():
    all_tacticity_70_40M.extend(all_40M_70[key]['Tacticity'])
    all_k_70_40M.extend(all_40M_70[key]['k'])
    all_dk_70_40M.extend(all_40M_70[key]['dk'])
    all_T_70_40M.extend(all_40M_70[key]['Tension'])
    all_dT_70_40M.extend(all_40M_70[key]['dTension'])
    all_L_70_40M.extend(all_40M_70[key]['L'])
    all_Cv_70_40M.extend(all_40M_70[key]['Cv'])
    all_orientations_70_40M.extend(all_40M_70[key]['Orientation'])

all_k_80_40M, all_dk_80_40M = [], []
all_tacticity_80_40M, all_T_80_40M, all_dT_80_40M, all_L_80_40M, all_Cv_80_40M = [], [], [], [], []
all_orientations_80_40M = []
for key in all_40M_80.keys():
    all_tacticity_80_40M.extend(all_40M_80[key]['Tacticity'])
    all_k_80_40M.extend(all_40M_80[key]['k'])
    all_dk_80_40M.extend(all_40M_80[key]['dk'])
    all_T_80_40M.extend(all_40M_80[key]['Tension'])
    all_dT_80_40M.extend(all_40M_80[key]['dTension'])
    all_L_80_40M.extend(all_40M_80[key]['L'])
    all_Cv_80_40M.extend(all_40M_80[key]['Cv'])
    all_orientations_80_40M.extend(all_40M_80[key]['Orientation'])

all_k_90_40M, all_dk_90_40M = [], []
all_tacticity_90_40M, all_T_90_40M, all_dT_90_40M, all_L_90_40M, all_Cv_90_40M = [], [], [], [], []
all_orientations_90_40M = []
for key in all_40M_90.keys():
    all_tacticity_90_40M.extend(all_40M_90[key]['Tacticity'])
    all_k_90_40M.extend(all_40M_90[key]['k'])
    all_dk_90_40M.extend(all_40M_90[key]['dk'])
    all_T_90_40M.extend(all_40M_90[key]['Tension'])
    all_dT_90_40M.extend(all_40M_90[key]['dTension'])
    all_L_90_40M.extend(all_40M_90[key]['L'])
    all_Cv_90_40M.extend(all_40M_90[key]['Cv'])
    all_orientations_90_40M.extend(all_40M_90[key]['Orientation'])

all_k_100_40M, all_dk_100_40M = [], []
all_tacticity_100_40M, all_T_100_40M, all_dT_100_40M, all_L_100_40M, all_Cv_100_40M = [], [], [], [], []
all_orientations_100_40M = []
for key in all_40M_100.keys():
    all_tacticity_100_40M.extend(all_40M_100[key]['Tacticity'])
    all_k_100_40M.extend(all_40M_100[key]['k'])
    all_dk_100_40M.extend(all_40M_100[key]['dk'])
    all_T_100_40M.extend(all_40M_100[key]['Tension'])
    all_dT_100_40M.extend(all_40M_100[key]['dTension'])
    all_L_100_40M.extend(all_40M_100[key]['L'])
    all_Cv_100_40M.extend(all_40M_100[key]['Cv'])
    all_orientations_100_40M.extend(all_40M_100[key]['Orientation'])

# %%
def get_T_unc(all_T, all_dT):

    all_T = np.array(all_T)
    all_dT = np.array(all_dT)
    unc = np.sqrt(np.std(all_T)**2 + np.mean(all_dT**2))
    return unc

# %%
def get_k_unc(all_k, all_dk):

    all_k = np.array(all_k)
    all_dk = np.array(all_dk)
    unc = np.sqrt(np.std(all_k)**2 + np.mean(all_dk**2))
    return unc

# %%
t_all_40M, k_all_40M, dk_all_40M = [], [], []
L_all_40M, T_all_40M, dT_all_40M = [], [], []



t_all_40M.extend([np.mean(all_tacticity_0_40M), np.mean(all_tacticity_10_40M), np.mean(all_tacticity_20_40M), np.mean(all_tacticity_30_40M), np.mean(all_tacticity_40_40M), \
              np.mean(all_tacticity_50_40M),\
              np.mean(all_tacticity_60_40M), np.mean(all_tacticity_70_40M), np.mean(all_tacticity_80_40M), np.mean(all_tacticity_90_40M), np.mean(all_tacticity_100_40M)])
k_all_40M.extend([np.mean(all_k_0_40M), np.mean(all_k_10_40M), np.mean(all_k_20_40M), np.mean(all_k_30_40M), np.mean(all_k_40_40M), \
              np.mean(all_k_50_40M), \
              np.mean(all_k_60_40M), np.mean(all_k_70_40M), np.mean(all_k_80_40M), np.mean(all_k_90_40M), np.mean(all_k_100_40M)])

L_all_40M.extend([np.mean(all_L_0_40M), np.mean(all_L_10_40M), np.mean(all_L_20_40M), np.mean(all_L_30_40M), np.mean(all_L_40_40M), \
              np.mean(all_L_50_40M), \
              np.mean(all_L_60_40M), np.mean(all_L_70_40M), np.mean(all_L_80_40M), np.mean(all_L_90_40M), np.mean(all_L_100_40M)])

T_all_40M.extend([np.mean(all_T_0_40M), np.mean(all_T_10_40M), np.mean(all_T_20_40M), np.mean(all_T_30_40M), np.mean(all_T_40_40M), \
              np.mean(all_T_50_40M), \
              np.mean(all_T_60_40M), np.mean(all_T_70_40M), np.mean(all_T_80_40M), np.mean(all_T_90_40M), np.mean(all_T_100_40M)])

dT_all_40M.extend([get_T_unc(all_T_0_40M, all_dT_0_40M), get_T_unc(all_T_10_40M, all_dT_10_40M), get_T_unc(all_T_20_40M, all_dT_20_40M), \
                get_T_unc(all_T_30_40M, all_dT_30_40M), get_T_unc(all_T_40_40M, all_dT_40_40M), get_T_unc(all_T_50_40M, all_dT_50_40M), get_T_unc(all_T_60_40M, all_dT_60_40M), \
                get_T_unc(all_T_70_40M, all_dT_70_40M), get_T_unc(all_T_80_40M, all_dT_80_40M), get_T_unc(all_T_90_40M, all_dT_90_40M), get_T_unc(all_T_100_40M, all_dT_100_40M)])

dk_all_40M.extend([get_k_unc(all_k_0_40M, all_dk_0_40M), get_k_unc(all_k_10_40M, all_dk_10_40M), get_k_unc(all_k_20_40M, all_dk_20_40M), \
                get_k_unc(all_k_30_40M, all_dk_30_40M), get_k_unc(all_k_40_40M, all_dk_40_40M), get_k_unc(all_k_50_40M, all_dk_50_40M), get_k_unc(all_k_60_40M, all_dk_60_40M), \
                get_k_unc(all_k_70_40M, all_dk_70_40M), get_k_unc(all_k_80_40M, all_dk_80_40M), get_k_unc(all_k_90_40M, all_dk_90_40M), get_k_unc(all_k_100_40M, all_dk_100_40M)])

# %%
t_all_40M = np.array(t_all_40M)
T_all_40M = np.array(T_all_40M)
dT_all_40M = np.array(dT_all_40M)

# %%
print(f"Syndiotactic PS: {k_all_40M[0]:.2f} +/- {dk_all_40M[0]:.2f} W/m-K")
# Out:
# Syndiotactic PS: 7.69 +/- 0.02 W/m-K

# %%
print(f"Isotactic PS: {k_all_40M[-1]:.2f} +/- {dk_all_40M[-1]:.2f} W/m-K")
# Out:
# Isotactic PS: 6.09 +/- 0.62 W/m-K

# %%
print(f"Minimum Thermal-k at {t_all_40M[np.argmin(k_all_40M)]:.0f}%: {k_all_40M[np.argmin(k_all_40M)]:.2f} +/- {dk_all_40M[np.argmin(k_all_40M)]:.2f} W/m-K")
# Out:
# Minimum Thermal-k at 69%: 2.54 +/- 0.28 W/m-K

# %%
print(f"Syndiotactic Enhancement: {k_all_40M[0]/np.min(k_all_40M):.1f}")
print(f"Isotactic Enhancement: {k_all_40M[-1]/np.min(k_all_40M):.1f}")
# Out:
# Syndiotactic Enhancement: 3.0
# Isotactic Enhancement: 2.4

# %%
print(f"Chain Length - Max: {np.max(L_all_40M):.2f} A, Min: {np.min(L_all_40M):.2f} A, Average: {np.mean(L_all_40M):.2f} A")
# Out:
# Chain Length - Max: 114.69 A, Min: 102.56 A, Average: 105.46 A

# %%
plt.figure(figsize=(3.375,4))
m = 8
plt.errorbar(t_all_40M/100, T_all_40M/1e3, yerr=dT_all_40M/1e3, fmt='o', capsize=5, label='40 Monomers', color='darkgreen', markerfacecolor='white', markersize=m)
plt.xlabel('Tacticity (%)')
plt.ylabel('Chain Tension (nN)')
plt.xlim(-0.05,1.05)
plt.ylim(0, 7)
# plt.savefig('PS_tension.svg', format='svg')
plt.show()

# %%
np.mean([np.mean(all_T_0_40M), np.mean(all_T_10_40M), np.mean(all_T_20_40M), np.mean(all_T_30_40M), np.mean(all_T_40_40M), \
         np.mean(all_T_50_40M), np.mean(all_T_60_40M), np.mean(all_T_70_40M), np.mean(all_T_80_40M), np.mean(all_T_90_40M), np.mean(all_T_100_40M)])
# Out:
# np.float64(2113.0094878891314)

# %%
print(f"Higher Chain Tension PS vs PP: {(2113.0094878891314 - 1679.8311413356112)/1679.8311413356112*100:.0f}%")
# Out:
# Higher Chain Tension PS vs PP: 26%

# %%
m = 8

plt.figure(figsize=(3.375,3.375))
plt.errorbar(t_all_40M, k_all_40M, yerr=dk_all_40M, fmt='o--', capsize=5, label='40 Monomers', color='darkgreen', markerfacecolor='white', markersize=m)

# plt.legend()
plt.ylim(0, 12)
plt.xlim(-5, 105)
# plt.yscale('log')
plt.xlabel('% Tacticity')
plt.ylabel('Thermal Conductivity (W/m-K)')
# plt.title('Polypropylene')
# plt.savefig('PS.svg', format='svg')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, sharex=True, sharey=True)
# Remove vertical space between Axes
fig.subplots_adjust(hspace=0.1)
fig.subplots_adjust(wspace=0.1)


axs[0][0].hist(all_k_10_40M, bins=20, label='10%', range=(0, 10), edgecolor='black', color='green')
axs[0][0].legend(loc='upper right')
axs[0][0].set_xlim(0,8)

axs[0][1].hist(all_k_20_40M, bins=20, label='20%', range=(0, 10), edgecolor='black', color='green')
axs[0][1].legend(loc='upper right')
axs[0][1].set_xlim(0,8)

axs[0][2].hist(all_k_30_40M, bins=20, label='30%', range=(0, 10), edgecolor='black', color='green')
axs[0][2].legend(loc='upper right')
axs[0][2].set_xlim(0,8)


axs[1][0].hist(all_k_40_40M, bins=20, label='40%', range=(0, 10), edgecolor='black', color='green')
axs[1][0].legend(loc='upper right')
axs[1][0].set_xlim(0,8)

axs[1][1].hist(all_k_50_40M, bins=20, label='50%', range=(0, 10), edgecolor='black', color='green')
axs[1][1].legend(loc='upper right')
axs[1][1].set_xlim(0,8)

axs[1][2].hist(all_k_60_40M, bins=20, label='60%', range=(0, 10), edgecolor='black', color='green')
axs[1][2].legend(loc='upper right')
axs[1][2].set_xlim(0,8)


axs[2][0].hist(all_k_70_40M, bins=20, label='70%', range=(0, 10), edgecolor='black', color='green')
axs[2][0].legend(loc='upper right')
axs[2][0].set_xlim(0,8)

axs[2][1].hist(all_k_80_40M, bins=20, label='80%', range=(0, 10), edgecolor='black', color='green')
axs[2][1].legend(loc='upper right')
axs[2][1].set_xlim(0,8)

axs[2][2].hist(all_k_90_40M, bins=20, label='90%', range=(0, 10), edgecolor='black', color='green')
axs[2][2].legend(loc='upper right')
axs[2][2].set_xlim(0,8)

# fig.supxlabel('Thermal Conductivity (W/m-K)')
# fig.supylabel('Count')
# fig.suptitle('Polystyrene 40 Monomers')

# plt.tight_layout()

# plt.savefig('PS_hist.svg', format='svg')
plt.show()

# %% [markdown]
# ## Kinetic Theory Analysis

# %%
all_V_0_40M = [np.sqrt(all_T_0_40M[i]*1e-22*all_L_0_40M[i]/(40*mass_PS)) for i in range(len(all_T_0_40M))] # in m/s
all_V_10_40M = [np.sqrt(all_T_10_40M[i]*1e-22*all_L_10_40M[i]/(40*mass_PS)) for i in range(len(all_T_10_40M))] # in m/s
all_V_20_40M = [np.sqrt(all_T_20_40M[i]*1e-22*all_L_20_40M[i]/(40*mass_PS)) for i in range(len(all_T_20_40M))] # in m/s
all_V_30_40M = [np.sqrt(all_T_30_40M[i]*1e-22*all_L_30_40M[i]/(40*mass_PS)) for i in range(len(all_T_30_40M))] # in m/s
all_V_40_40M = [np.sqrt(all_T_40_40M[i]*1e-22*all_L_40_40M[i]/(40*mass_PS)) for i in range(len(all_T_40_40M))] # in m/s
all_V_50_40M = [np.sqrt(all_T_50_40M[i]*1e-22*all_L_50_40M[i]/(40*mass_PS)) for i in range(len(all_T_50_40M))] # in m/s
all_V_60_40M = [np.sqrt(all_T_60_40M[i]*1e-22*all_L_60_40M[i]/(40*mass_PS)) for i in range(len(all_T_60_40M))] # in m/s
all_V_70_40M = [np.sqrt(all_T_70_40M[i]*1e-22*all_L_70_40M[i]/(40*mass_PS)) for i in range(len(all_T_70_40M))] # in m/s
all_V_80_40M = [np.sqrt(all_T_80_40M[i]*1e-22*all_L_80_40M[i]/(40*mass_PS)) for i in range(len(all_T_80_40M))] # in m/s
all_V_90_40M = [np.sqrt(all_T_90_40M[i]*1e-22*all_L_90_40M[i]/(40*mass_PS)) for i in range(len(all_T_90_40M))] # in m/s
all_V_100_40M = [np.sqrt(all_T_100_40M[i]*1e-22*all_L_100_40M[i]/(40*mass_PS)) for i in range(len(all_T_100_40M))] # in m/s

# %%
iso_V = np.mean(all_V_100_40M)
syn_V = np.mean(all_V_0_40M)

print(f"Higher Wave Speed of Isotactic/Syndiotactic: {iso_V/syn_V:.0f}")
# Out:
# Higher Wave Speed of Isotactic/Syndiotactic: 4

# %%
all_mfp_0_40M = [all_k_0_40M[i]/all_Cv_0_40M[i]/all_V_0_40M[i]*1e9 for i in range(len(all_V_0_40M))] # in nm
all_mfp_10_40M = [all_k_10_40M[i]/all_Cv_10_40M[i]/all_V_10_40M[i]*1e9 for i in range(len(all_V_10_40M))] # in nm
all_mfp_20_40M = [all_k_20_40M[i]/all_Cv_20_40M[i]/all_V_20_40M[i]*1e9 for i in range(len(all_V_20_40M))] # in nm
all_mfp_30_40M = [all_k_30_40M[i]/all_Cv_30_40M[i]/all_V_30_40M[i]*1e9 for i in range(len(all_V_30_40M))] # in nm
all_mfp_40_40M = [all_k_40_40M[i]/all_Cv_40_40M[i]/all_V_40_40M[i]*1e9 for i in range(len(all_V_40_40M))] # in nm
all_mfp_50_40M = [all_k_50_40M[i]/all_Cv_50_40M[i]/all_V_50_40M[i]*1e9 for i in range(len(all_V_50_40M))] # in nm
all_mfp_60_40M = [all_k_60_40M[i]/all_Cv_60_40M[i]/all_V_60_40M[i]*1e9 for i in range(len(all_V_60_40M))] # in nm
all_mfp_70_40M = [all_k_70_40M[i]/all_Cv_70_40M[i]/all_V_70_40M[i]*1e9 for i in range(len(all_V_70_40M))] # in nm
all_mfp_80_40M = [all_k_80_40M[i]/all_Cv_80_40M[i]/all_V_80_40M[i]*1e9 for i in range(len(all_V_80_40M))] # in nm
all_mfp_90_40M = [all_k_90_40M[i]/all_Cv_90_40M[i]/all_V_90_40M[i]*1e9 for i in range(len(all_V_90_40M))] # in nm
all_mfp_100_40M = [all_k_100_40M[i]/all_Cv_100_40M[i]/all_V_100_40M[i]*1e9 for i in range(len(all_V_100_40M))] # in nm

# %%
print(f"Tacticity at which minimum thermal conductivity: {t_all_40M[np.argmin(k_all_40M)]:.0f}%")
# Out:
# Tacticity at which minimum thermal conductivity: 69%

# %%
print(f"MFP Enhancement for Syndiotactic: {np.mean(all_mfp_0_40M)/np.mean(all_mfp_70_40M):.0f}x")
# Out:
# MFP Enhancement for Syndiotactic: 7x

# %%
print(f"MFP Enhancement for Isotactic: {(np.mean(all_mfp_100_40M)-np.mean(all_mfp_70_40M))/np.mean(all_mfp_70_40M)*100:.0f}%")
# Out:
# MFP Enhancement for Isotactic: 51%

# %%
mfp_all_40M = np.array([np.mean(all_mfp_0_40M), np.mean(all_mfp_10_40M), np.mean(all_mfp_20_40M), np.mean(all_mfp_30_40M), np.mean(all_mfp_40_40M), \
                        np.mean(all_mfp_50_40M), \
                        np.mean(all_mfp_60_40M), np.mean(all_mfp_70_40M), np.mean(all_mfp_80_40M), np.mean(all_mfp_90_40M), np.mean(all_mfp_100_40M)])
dmfp_all_40M = np.array([np.std(all_mfp_0_40M), np.std(all_mfp_10_40M), np.std(all_mfp_20_40M), np.std(all_mfp_30_40M), np.std(all_mfp_40_40M), \
                        np.std(all_mfp_50_40M), \
                        np.std(all_mfp_60_40M), np.std(all_mfp_70_40M), np.std(all_mfp_80_40M), np.std(all_mfp_90_40M), np.std(all_mfp_100_40M)])

# %%
cmap = mpl.colormaps.get_cmap('Spectral_r')
# norm = mpl.colors.Normalize(min(color_k), max(color_k))
norm = mpl.colors.Normalize(2,8)
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)

m1, m2 = 'o', 's'
s = 10
w = 1
########## 40 Monomers ###########

for i in range(len(all_tacticity_10_40M)):
    plt.plot(all_tacticity_10_40M[i], all_mfp_10_40M[i], m1, markerfacecolor=cmap(norm(all_k_10_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_20_40M)):
    plt.plot(all_tacticity_20_40M[i], all_mfp_20_40M[i], m1, markerfacecolor=cmap(norm(all_k_20_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_30_40M)):
    plt.plot(all_tacticity_30_40M[i], all_mfp_30_40M[i], m1, markerfacecolor=cmap(norm(all_k_30_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_40_40M)):
    plt.plot(all_tacticity_40_40M[i], all_mfp_40_40M[i], m1, markerfacecolor=cmap(norm(all_k_40_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_50_40M)):
    plt.plot(all_tacticity_50_40M[i], all_mfp_50_40M[i], m1, markerfacecolor=cmap(norm(all_k_50_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_60_40M)):
    plt.plot(all_tacticity_60_40M[i], all_mfp_60_40M[i], m1, markerfacecolor=cmap(norm(all_k_60_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_70_40M)):
    plt.plot(all_tacticity_70_40M[i], all_mfp_70_40M[i], m1, markerfacecolor=cmap(norm(all_k_70_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_80_40M)):
    plt.plot(all_tacticity_80_40M[i], all_mfp_80_40M[i], m1, markerfacecolor=cmap(norm(all_k_80_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_90_40M)):
    plt.plot(all_tacticity_90_40M[i], all_mfp_90_40M[i], m1, markerfacecolor=cmap(norm(all_k_90_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

plt.errorbar(t_all_40M[1:-1], mfp_all_40M[1:-1], yerr=dmfp_all_40M[1:-1], fmt='o', capsize=5, color='black', ms=s, mew=w, elinewidth=w, markerfacecolor='white', label='Average MFP')

plt.plot(np.mean(all_tacticity_0_40M), np.mean(all_mfp_0_40M), m1, markerfacecolor=cmap(norm(np.mean(all_k_0_40M))), markeredgecolor='black', markersize=s, markeredgewidth=w)
plt.plot(np.mean(all_tacticity_100_40M), np.mean(all_mfp_100_40M), m1, markerfacecolor=cmap(norm(np.mean(all_k_100_40M))), markeredgecolor='black', markersize=s, markeredgewidth=w)

plt.colorbar(sm, label='Thermal Conductivity (W/m-K)', ax=plt.gca())
plt.xlabel('% Tacticity')
plt.ylabel('Avg. Mean Free Path (nm)')
plt.xlim(-5, 105)
plt.ylim(0, 3)
plt.legend()
# plt.title('Polystyrene')
# plt.savefig('PS_mfp.svg', format='svg')
plt.show()

# %%
V_all_40M = np.array([np.mean(all_V_0_40M)/1000, np.mean(all_V_10_40M)/1000, np.mean(all_V_20_40M)/1000, np.mean(all_V_30_40M)/1000, np.mean(all_V_40_40M)/1000, \
                        np.mean(all_V_50_40M)/1000, \
                        np.mean(all_V_60_40M)/1000, np.mean(all_V_70_40M)/1000, np.mean(all_V_80_40M)/1000, np.mean(all_V_90_40M)/1000, np.mean(all_V_100_40M)/1000])
dV_all_40M = np.array([np.std(all_V_0_40M)/1000, np.std(all_V_10_40M)/1000, np.std(all_V_20_40M)/1000, np.std(all_V_30_40M)/1000, np.std(all_V_40_40M)/1000, \
                        np.std(all_V_50_40M)/1000, \
                        np.std(all_V_60_40M)/1000, np.std(all_V_70_40M)/1000, np.std(all_V_80_40M)/1000, np.std(all_V_90_40M)/1000, np.std(all_V_100_40M)/1000])

# %%
cmap = mpl.colormaps.get_cmap('Spectral_r')
# norm = mpl.colors.Normalize(min(color_k), max(color_k))
norm = mpl.colors.Normalize(2, 8)
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)

m1, m2 = 'o', 's'
s = 10
w = 1
########## 40 Monomers ###########

for i in range(len(all_tacticity_10_40M)):
    plt.plot(all_tacticity_10_40M[i], all_V_10_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_10_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_20_40M)):
    plt.plot(all_tacticity_20_40M[i], all_V_20_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_20_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_30_40M)):
    plt.plot(all_tacticity_30_40M[i], all_V_30_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_30_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_40_40M)):
    plt.plot(all_tacticity_40_40M[i], all_V_40_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_40_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_50_40M)):
    plt.plot(all_tacticity_50_40M[i], all_V_50_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_50_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_60_40M)):
    plt.plot(all_tacticity_60_40M[i], all_V_60_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_60_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_70_40M)):
    plt.plot(all_tacticity_70_40M[i], all_V_70_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_70_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_80_40M)):
    plt.plot(all_tacticity_80_40M[i], all_V_80_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_80_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

for i in range(len(all_tacticity_90_40M)):
    plt.plot(all_tacticity_90_40M[i], all_V_90_40M[i]/1000, m1, markerfacecolor=cmap(norm(all_k_90_40M[i])), markeredgecolor='black', markersize=s, markeredgewidth=w)

plt.errorbar(t_all_40M[1:-1], V_all_40M[1:-1], yerr=dV_all_40M[1:-1], fmt='o', capsize=5, color='black', ms=s, mew=w, elinewidth=w, markerfacecolor='white', label='Average V')

plt.plot(np.mean(all_tacticity_0_40M), np.mean(all_V_0_40M)/1000, m1, markerfacecolor=cmap(norm(np.mean(all_k_0_40M))), markeredgecolor='black', markersize=s, markeredgewidth=w)
plt.plot(np.mean(all_tacticity_100_40M), np.mean(all_V_100_40M)/1000, m1, markerfacecolor=cmap(norm(np.mean(all_k_100_40M))), markeredgecolor='black', markersize=s, markeredgewidth=w)


plt.colorbar(sm, label='Thermal Conductivity (W/m-K)', ax=plt.gca())
plt.xlabel('% Tacticity')
plt.ylabel('Wave Speed (km/s)')
plt.xlim(-5, 105)
plt.ylim(0, 5)
plt.legend()
# plt.title('Polystyrene')
# plt.savefig('PS_v.svg', format='svg')
plt.show()

# %% [markdown]
# ## Deformation

# %%
data = np.load('PS_deform_40_monomers.npz')
ep=data['ep']
strains = data['strains']
k= data['k']
dk= data['dk']
T= data['T']
tacticity= data['tacticity']

# %%
cmap = mpl.colormaps.get_cmap('Spectral_r')
norm = mpl.colors.Normalize(np.min(T), np.max(T))
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)

all_markers = ['^', 'd', 's', 'o', 'h', 'v']
size = 10

for i, t in enumerate(tacticity):

    if i == 0:
        ep_0 = ep[i, ~np.isnan(k[i])]
        k_0 = k[i, ~np.isnan(k[i])]
        T_0 = k[i, ~np.isnan(k[i])]
        plt.plot(ep_0, k_0, f"{all_markers[i]}--", markerfacecolor='white', color='black', markersize=size, label=f'{t}%')
        for j in range(len(ep_0)):
                    plt.plot(ep_0[j], k_0[j], f"{all_markers[i]}", markerfacecolor=cmap(norm(T_0[j])), markeredgecolor='black', markersize=size)
        continue
    else:
        plt.plot(ep[i], k[i], f"{all_markers[i]}--", markerfacecolor='white', color='black', markersize=size, label=f'{t}%')
        for j in range(len(ep[i])):
                    plt.plot(ep[i,j], k[i,j], f"{all_markers[i]}", markerfacecolor=cmap(norm(T[i,j])), markeredgecolor='black', markersize=size)

plt.colorbar(sm, label='Chain Tension (pN)', ax=plt.gca())
plt.legend()
plt.ylabel('Thermal Conductivity (W/m-K)')
plt.xlabel('Strain (%)')
plt.yscale('log')
plt.xlim(-12, 12)
plt.ylim(1,30)
# plt.title('Polystyrene')
plt.tight_layout()
# plt.savefig('PS_strain.svg', format='svg')
plt.show()

# %% [markdown]
# ### Dihedral Angles

# %%
from scipy.stats import gaussian_kde

# %%
with open(f'PS_dihedral_40.pickle', 'rb') as f:
    data = pickle.load(f)

d_all_0 = data["0"]["Dihedrals"]
d_all_10 = data["10"]["Dihedrals"]
d_all_20 = data["20"]["Dihedrals"]
d_all_30 = data["30"]["Dihedrals"]
d_all_40 = data["40"]["Dihedrals"]
d_all_50 = data["50"]["Dihedrals"]
d_all_60 = data["60"]["Dihedrals"]
d_all_70 = data["70"]["Dihedrals"]
d_all_80 = data["80"]["Dihedrals"]
d_all_90 = data["90"]["Dihedrals"]
d_all_100 = data["100"]["Dihedrals"]

b = 0.25
kde_0 = gaussian_kde(d_all_0, bw_method=b)
kde_10 = gaussian_kde(d_all_10, bw_method=b)
kde_20 = gaussian_kde(d_all_20, bw_method=b)
kde_30 = gaussian_kde(d_all_30, bw_method=b)
kde_40 = gaussian_kde(d_all_40, bw_method=b)
kde_50 = gaussian_kde(d_all_50, bw_method=b)
kde_60 = gaussian_kde(d_all_60, bw_method=b)
kde_70 = gaussian_kde(d_all_70, bw_method=b)
kde_80 = gaussian_kde(d_all_80, bw_method=b)
kde_90 = gaussian_kde(d_all_90, bw_method=b)
kde_100 = gaussian_kde(d_all_100, bw_method=b)

angle = np.linspace(0, 360, 361, endpoint=True)
d0 = kde_0(angle)
d10 = kde_10(angle)
d20 = kde_20(angle)
d30 = kde_30(angle)
d40 = kde_40(angle)
d50 = kde_50(angle)
d60 = kde_60(angle)
d70 = kde_70(angle)
d80 = kde_80(angle)
d90 = kde_90(angle)
d100 = kde_100(angle)

cmap = mpl.colormaps.get_cmap('autumn')
norm = mpl.colors.Normalize(0, 100)
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)

# Plot each graph, and manually set the y tick values
plt.figure(figsize=(5,5))

plt.plot(angle, d20, label='20%', color=cmap(norm(20)))
plt.plot(angle, d40, label='40%', color=cmap(norm(40)))
plt.plot(angle, d60, label='60%', color=cmap(norm(60)))
plt.plot(angle, d80, label='80%', color=cmap(norm(80)))

plt.plot(angle, d0, label='0%', color='black')
plt.plot(angle, d100, label='100%', color='purple')


plt.xlabel('Dihedral Angle (degrees)')
plt.ylabel('Probability')
plt.title('Polystyrene (40 Monomers)')
plt.legend()
plt.tight_layout()

plt.xlim(0,360)
plt.ylim(0, 0.03)

# plt.savefig('PS_dihedral_40.svg', format='svg')

plt.show()
